# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import pandas as pd
import numpy as np
import os
import plotly.express as px
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df_shehjar_second_sensor1 = pd.read_csv("/Users/shehjarsadhu/Desktop/UniversityOfRhodeIsland/BSN_2024/MedDock/Results_Discussion/Shehjar_second_sensor_data_20240517-140204.csv")

# %%
df_shehjar_second_sensor1
# Out:
#       FSR  Time        Date   Milli
# 0     274    14  17/05/2024   43737
# 1     277    14  17/05/2024   43768
# 2     274    14  17/05/2024   43799
# 3     276    14  17/05/2024   43830
# 4     274    14  17/05/2024   43861
# ...   ...   ...         ...     ...
# 4658  283    14  17/05/2024  594973
# 4659  282    14  17/05/2024  595004
# 4660  283    14  17/05/2024  595041
# 4661  283    14  17/05/2024  595095
# 4662  283    14  17/05/2024  595150
#
# [4663 rows x 4 columns]

# %%
x = df_shehjar_second_sensor1["FSR"]
peaks_pill_drop, _ = find_peaks(x, height=300,distance=220)

# %%
fig = make_subplots()

# Adding the main line plot
fig.add_trace(go.Scatter(y=x, mode='lines', name='FSR'))

# Adding the peaks
fig.add_trace(go.Scatter(x=peaks_pill_drop, y=x[peaks_pill_drop], mode='markers', marker=dict(symbol='x', size=10), name='Peaks'))

# Adding the zero line
# fig.add_trace(go.Scatter(y=np.zeros_like(x), mode='lines', line=dict(dash='dash', color='gray'), name='Zero Line'))

# Show plot
fig.show()

# %%
peaks_pill_drop, _ = find_peaks(x,height=(None, 256),distance=215) #height=30,threshold=20 ,height=100,threshold=20,distance=220
fig1 = make_subplots()
# Adding the main line plot
fig1.add_trace(go.Scatter(y=x, mode='lines', name='FSR'))
# Adding the peaks
fig1.add_trace(go.Scatter(x=peaks_pill_drop, y=x[peaks_pill_drop], mode='markers', marker=dict(symbol='x', size=10), name='Peaks'))
# Show plot
fig1.show()
